# %%
import os 
os.chdir("/Volumes/Pegasus_wangyun/ADHD/ITA/MRI/Preprocess")
cwd=os.getcwd()
print(cwd)
os.listdir('./')
# Out:
# /Volumes/Pegasus_wangyun/ADHD/ITA/MRI/Preprocess
# ['.DS_Store',
#  'anatomical_input.txt',
#  'JSON_need_modify.txt',
#  'rest_input.txt',
#  'Simon_input.txt',
#  'sub-10002',
#  'sub-10033',
#  'sub-10046',
#  'sub-10050',
#  'sub-10057',
#  'sub-10109',
#  'sub-10137',
#  'sub-10170',
#  'sub-10186',
#  'sub-10200',
#  'sub-10209',
#  'sub-10315',
#  'sub-10338',
#  'sub-10345',
#  'sub-10353',
#  'sub-10360',
#  'sub-10407',
#  'sub-10465',
#  'sub-10547',
#  'sub-10952',
#  'sub-10997',
#  'sub-11047',
#  'sub-12001',
#  'sub-12013',
#  'sub-12162',
#  'sub-12163',
#  'sub-12201',
#  'sub-12320',
#  'sub-12431',
#  'sub-12492',
#  'sub-12622',
#  'sub-12623',
#  'sub-12656',
#  'sub-12729',
#  'sub-12790',
#  'sub-12899',
#  'sub-12995',
#  'sub-13128',
#  'sub-13209',
#  'sub-13337',
#  'sub-13631',
#  'sub-14025',
#  'sub-14030',
#  'sub-14058',
#  'sub-14213',
#  'sub-14254',
#  'sub-14322',
#  'sub-14330',
#  'sub-14374',
#  'sub-14494',
#  'sub-14543',
#  'sub-14586',
#  'sub-14701',
#  'sub-14745',
#  'sub-14763',
#  'sub-14784',
#  'sub-14804',
#  'sub-14820',
#  'sub-15108',
#  'sub-15110',
#  'sub-15159',
#  'sub-15491',
#  'sub-15693',
#  'sub-16112',
#  'sub-16291',
#  'sub-6416',
#  'sub-6496',
#  'sub-6510',
#  'sub-6518',
#  'sub-6593',
#  'sub-6661',
#  'sub-6715',
#  'sub-6773',
#  'sub-6785',
#  'sub-6851',
#  'sub-6860',
#  'sub-6866',
#  'sub-6917',
#  'sub-6998',
#  'sub-7016',
#  'sub-7031',
#  'sub-7192',
#  'sub-7333',
#  'sub-7394',
#  'sub-7405',
#  'sub-7476',
#  'sub-7603',
#  'sub-7637',
#  'sub-7659',
#  'sub-7701',
#  'sub-7709',
#  'sub-7790',
#  'sub-7839',
#  'sub-7881',
#  'sub-7911',
#  'sub-7936',
#  'sub-8088',
#  'sub-8168',
#  'sub-8410',
#  'sub-8415',
#  'sub-8433',
#  'sub-8437',
#  'sub-8470',
#  'sub-8491',
#  'sub-8501',
#  'sub-8508',
#  'sub-8511',
#  'sub-8517',
#  'sub-8525',
#  'sub-8596',
#  'sub-8644',
#  'sub-8653',
#  'sub-8744',
#  'sub-8750',
#  'sub-8794',
#  'sub-8813',
#  'sub-8814',
#  'sub-8819',
#  'sub-8869',
#  'sub-8874',
#  'sub-8967',
#  'sub-8985',
#  'sub-8992',
#  'sub-8996',
#  'sub-9017',
#  'sub-9032',
#  'sub-9044',
#  'sub-9049',
#  'sub-9077',
#  'sub-9130',
#  'sub-9140',
#  'sub-9181',
#  'sub-9204',
#  'sub-9215',
#  'sub-9218',
#  'sub-9246',
#  'sub-9254',
#  'sub-9260',
#  'sub-9269',
#  'sub-9280',
#  'sub-9285',
#  'sub-9290',
#  'sub-9300',
#  'sub-9312',
#  'sub-9325',
#  'sub-9341',
#  'sub-9345',
#  'sub-9349',
#  'sub-9358',
#  'sub-9367',
#  'sub-9382',
#  'sub-9436',
#  'sub-9446',
#  'sub-9557',
#  'sub-9677',
#  'sub-9681',
#  'sub-9690',
#  'sub-9719',
#  'sub-9738',
#  'sub-9752',
#  'sub-9767',
#  'sub-9772',
#  'sub-9816',
#  'sub-9824',
#  'sub-9869',
#  'sub-9908',
#  'sub-9931',
#  'sub-9943',
#  'sub-9953',
#  'sub-9997']

# %%
import json
import pandas as pd

with open('JSON_need_modify.txt') as f:
       for line in f:
            with open(f) as json_data:
                data=json.load(json_data)
                TR=data['RepetitionTime']
 
                if TR==2:
                    ST=pd.read_csv('/Users/posnerlab/Documents/GitHub/ADHD_ITA/ST2.csv')
                else:
                    ST=pd.read_csv('/Users/posnerlab/Documents/GitHub/ADHD_ITA/ST22.csv')

                list(ST.ST)
                data['SliceTiming']=list(ST.ST)
                data['SliceTiming']
                with open(f,'w') as outfile:
                        json.dump(data,outfile)

                #print(data)
# Out:
# {'Modality': 'MR', 'MagneticFieldStrength': 3, 'Manufacturer': 'GE', 'ManufacturersModelName': 'DISCOVERY_MR750', 'InstitutionName': 'NYS_PSYCHIATRIC_INST', 'DeviceSerialNumber': '0000000000001234', 'StationName': 'GEMSOW', 'PatientPosition': 'HFS', 'ProcedureStepDescription': 'posnita', 'SoftwareVersions': '24_LX_MR_Software_release:DV24.0_R01_1344.a', 'MRAcquisitionType': '2D', 'SeriesDescription': 'FUNC_EPI_Resting_V155_S34', 'ProtocolName': 'FUNC_EPI_Resting_V155_S34', 'ScanningSequence': 'EP_RM', 'SequenceVariant': 'NONE', 'ScanOptions': 'EPI_GEMS', 'ImageType': ['ORIGINAL', 'PRIMARY', 'EPI', 'NONE'], 'SeriesNumber': 3, 'AcquisitionTime': '10:19:48.000000', 'AcquisitionNumber': 1, 'SliceThickness': 3.5, 'SpacingBetweenSlices': 3.5, 'SAR': 0.3035, 'EchoTime': 0.03, 'RepetitionTime': 2, 'FlipAngle': 90, 'PercentPhaseFOV': 100, 'AcquisitionMatrixPE': 64, 'ReconMatrixPE': 64, 'EffectiveEchoSpacing': 0.000388, 'TotalReadoutTime': 0.024444, 'PixelBandwidth': 7812.5, 'ImageOrientationPatientDICOM': [0.999898, -0.00142937, -0.014179, 0.000126584, 0.995809, -0.0914582], 'InPlanePhaseEncodingDirectionDICOM': 'COL', 'ConversionSoftware': 'dcm2niix', 'ConversionSoftwareVersion': 'v1.0.20171215 (OpenJPEG build) Clang9.0.0'}

# %%
TR=data['RepetitionTime']
import pandas as pd 
if TR==2:
    ST=pd.read_csv('/Users/posnerlab/Documents/GitHub/ADHD_ITA/ST2.csv')
else:
    ST=pd.read_csv('/Users/posnerlab/Documents/GitHub/ADHD_ITA/ST22.csv')
    
list(ST.ST)
data['SliceTiming']=list(ST.ST)
data['SliceTiming']
#print(data)

with open('sub-01_task-rest_run01_bold.json','w') as outfile:
    json.dump(data,outfile)

# %%
print(data)
# Out:
# {'Modality': 'MR', 'MagneticFieldStrength': 3, 'Manufacturer': 'GE', 'ManufacturersModelName': 'DISCOVERY_MR750', 'InstitutionName': 'NYS_PSYCHIATRIC_INST', 'DeviceSerialNumber': '0000000000001234', 'StationName': 'GEMSOW', 'PatientPosition': 'HFS', 'ProcedureStepDescription': 'posnita', 'SoftwareVersions': '24_LX_MR_Software_release:DV24.0_R01_1344.a', 'MRAcquisitionType': '2D', 'SeriesDescription': 'FUNC_EPI_Resting_V155_S34', 'ProtocolName': 'FUNC_EPI_Resting_V155_S34', 'ScanningSequence': 'EP_RM', 'SequenceVariant': 'NONE', 'ScanOptions': 'EPI_GEMS', 'ImageType': ['ORIGINAL', 'PRIMARY', 'EPI', 'NONE'], 'SeriesNumber': 3, 'AcquisitionTime': '10:19:48.000000', 'AcquisitionNumber': 1, 'SliceThickness': 3.5, 'SpacingBetweenSlices': 3.5, 'SAR': 0.3035, 'EchoTime': 0.03, 'RepetitionTime': 2, 'FlipAngle': 90, 'PercentPhaseFOV': 100, 'AcquisitionMatrixPE': 64, 'ReconMatrixPE': 64, 'EffectiveEchoSpacing': 0.000388, 'TotalReadoutTime': 0.024444, 'PixelBandwidth': 7812.5, 'ImageOrientationPatientDICOM': [0.999898, -0.00142937, -0.014179, 0.000126584, 0.995809, -0.0914582], 'InPlanePhaseEncodingDirectionDICOM': 'COL', 'ConversionSoftware': 'dcm2niix', 'ConversionSoftwareVersion': 'v1.0.20171215 (OpenJPEG build) Clang9.0.0', 'SliceTiming': [0.0, 1.0, 0.058823529000000006, 1.058823529, 0.117647059, 1.117647059, 0.176470588, 1.176470588, 0.235294118, 1.2352941179999999, 0.294117647, 1.294117647, 0.352941176, 1.3529411759999999, 0.41176470600000004, 1.411764706, 0.470588235, 1.470588235, 0.529411765, 1.529411765, 0.588235294, 1.588235294, 0.647058824, 1.6470588240000001, 0.705882353, 1.705882353, 0.764705882, 1.764705882, 0.8235294120000001, 1.8235294119999998, 0.882352941, 1.882352941, 0.9411764709999999, 1.941176471]}
